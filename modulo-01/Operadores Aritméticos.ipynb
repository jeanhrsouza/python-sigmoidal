# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Python do Zero**
#
# ---
#
# ### Operadores Aritméticos
#
# <center>
# <img alt = "Math" width = "35%" src = "https://image.freepik.com/free-psd/flat-lay-pi-sign-mathematics_23-2148458911.jpg">
# </center>
#
# Nesta aula, o assunto tratado serão os operadores aritméticos do Python, além da sua ordem de precedência quando compondo uma expressão matemática.
#
# Os operadores aritméticos do Python são:
# * `+` Adição
# * `-` Subtração
# * `*` Multiplicação
# * `/` Divisão
# * `**` Exponenciação
# * `//` Divisão (resultado inteiro)
#
# Abaixo, podemos ver exemplos do uso desses operadores.

# %%
#Adicao
13 + 45 + 89 + 90
# Out:
# 237

# %%
# Subtração
87 - 700
# Out:
# -613

# %%
# Multiplicação
7 * 10
# Out:
# 70

# %%
# Divisão
70 / 3
# Out:
# 23.333333333333332

# %%
# Divisão (resultado inteiro)
70 // 3
# Out:
# 23

# %% [markdown]
# $$
# 7 ^2
# $$

# %%
# exponenciação
7 ** 2
# Out:
# 49

# %% [markdown]
# ###Ordem de precedência
# Caso faça tempo desde o seu último contato com a matemática, vale a pena relembrarmos a ordem correta das operações matemáticas.
#
# $$
# \begin{aligned}
# x & = 3 + 10 * 3 \\
# x & = 3 + 30 \\
# x & = 33
# \end{aligned}
# $$
#
# Lembre-se que a ordem das operações matemáticas é:
#
# * 1º Parêntesis;
# * 2º Expoentes;
# * 3º Multiplicações e Divisões; (da esquerda para a direita)
# * 4º Somas e Subtrações. (da esquerda para a direita)
#
# Vamos ver como isso funciona na prática com Python.

# %%
#primeiro é resolvida a multiplicação e depois a subtração
10 * 3
# Out:
# 30

# %%
# multiplicamos, e depois somamos o resultado
3 + 30
# Out:
# 33

# %% [markdown]
# Mesmo acrescentando um pouquinho de complexidade, o Python consegue lidar com extrema facilidade, cabendo a nós termos atenção às operações realizadas.
# $$
# \begin{aligned}
# x & = 5 + 9 - 2^2 + \frac{9}{3}\\
# x & = 5 + 9 - 4 + \frac {9}{3} \\
# x & = 5 + 9 - 4 + 3 \\
# x & = 14 - 4 + 3 \\
# x & = 10 + 3 \\
# x & = 13 \\
# \end{aligned}
# $$

# %%
# Resolução da equação acima usando python
5 + 9 - 2**2 + 9/3
# Out:
# 13.0

# %%
5 + 9 - (2**2) + (9/3)
# Out:
# 13.0

# %% [markdown]
# Expressões maiores podem confundir, então o segredo é anotar a correta ordem de execução das operações matemáticas:
#
# 1. Parêntesis
# 2. Expoentes
# 3. Multiplicações e Divisões (esquerda para a direita)
# 4. Somas e subtrações (esquerda para a direita)
#
# #### Exemplo 1
# Calcular a média simples das notas das 3 provas de matemática
# * Nota 1 = 8,5
# * Nota 2 = 9,2
# * Nota 3 = 7,5

# %%
#resposta
(8.5 + 9.2 + 7.5) / 3
# Out:
# 8.4

# %% [markdown]
# #### Exemplo 2
# Qual a área de
# * O volume de uma esfera é calculada por meio da expressão $V = \frac{4}{3} \pi r^3$.
# * Calcule o volume de uma esfera de 5 metros?

# %%
#resposta 
4 / 3 * (3.14) * 5 ** 3
# Out:
# 523.3333333333334

# %%
# resposta
(4/3) * (3.14) * (5**3)
# Out:
# 523.3333333333334

# %% [markdown]
# ### Exercícios
# Agora que vimos como utilizar os operadores, vamos resolver algumas equações.
# <center><img alt="Math" width="35%" src="https://image.freepik.com/free-vector/people-budgeting-order-plan-personal-finance_53876-64613.jpg"></center>

# %% [markdown]
# #### Exercício 1
# Calcule:
# \begin{aligned}
# x & = 15 - 5 + 3^2 \\
# \end{aligned}

# %%
# resposta
15 - 5 + (3**2)
# Out:
# 19

# %% [markdown]
# #### Exercício 2
# Calcule:
# \begin{aligned}
#  x & = 20 + 5/7 * 9
# \end{aligned}

# %%
#Resposta
20 + (5 / 7) * 9
# Out:
# 26.42857142857143

# %% [markdown]
# #### Exercício 3
# Calcule:
# \begin{aligned}
# x & = 17*3-4^2/3
# \end{aligned}

# %%
(17 * 3) - (4**2 /3)
# Out:
# 45.666666666666664
